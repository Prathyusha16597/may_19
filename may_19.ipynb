# %%
name=input("Enter a NAME : ")
while True:
    age=int(input("Enter a AGE : "))
    if 30<=age<=75:
        break
    else:
        print("INVALIED AGE")
while True:
    sex=input('''1.Male
                 2.Female''')
    if sex=="1" or sex=="2":
        break
ldl=float(input("Enter a LDL CHOLESTEROL : "))
hdl=float(input("Enter a HDL CHOLESTEROL : "))
while True:
    smoke=input("DO you SMOKE ?y/n : ")
    if smoke=='y' or smoke=='Y':
        break
    elif smoke=='n' or smoke=='N':
        break
while True:
    diabetes=input("You have a DIABETES ?y/n : ")
    if diabetes=='y' or diabetes=='Y':
        break
    elif diabetes=='n' or diabetes=="N":
        break
if True:
    bps=int(input("Enter a SYSTOLE : "))
    bpd=int(input("Enter a DIASToLE : "))

class HeartCal:
    def __init__(self,sex,age,ldl,hdl,smoke,diabetes,bps,bpd):
        self.age=age
        self.sex=sex
        self.ldl=ldl
        self.hdl=hdl
        self.smoke=smoke
        self.diabetes=diabetes
        self.bps=bps
        self.bpd=bpd
    def age_calc(self):
        if self.sex=='1':
            if 30<=self.age<=34:
                return -1
            elif 35<=self.age<=39:
                return 0
            elif 40<=self.age<=44:
                return -1
            elif 45<=self.age<=49:
                return +2
            elif 50<=self.age<=54:
                return +3
            elif 55<=self.age<=59:
                return +4
            elif 60<=self.age<=64:
                return +5
            elif 65<=self.age<=69:
                return +6
            elif 70<=self.age<=74:
                return +7
        elif self.sex=="2":
            if 30<=self.age<=34:
                return -9
            elif 35<=self.age<=39:
                return -4
            elif 40<=self.age<=44:
                return 0
            elif 45<=self.age<=49:
                return +3
            elif 50<=self.age<=54:
                return +6
            elif 55<=self.age<=59:
                return +7
            elif 60<=self.age<=64:
                return +8
            elif 65<=self.age<=69:
                return +8
            elif 70<=self.age<=74:
                return +8
    def ldl_cho_calc(self):
        if self.sex=="1":
            if self.ldl<=100:
                return -3
            elif 101<=self.ldl<=129:
                return 0
            elif 130<=self.ldl<=159:
                return 0
            elif 160<=self.ldl<=189:
                return +1
            elif self.ldl>=190:
                return +2
        elif self.sex=="2":
            if self.ldl<=100:
                return -2
            elif 101<=self.ldl<=129:
                return 0
            elif 130<=self.ldl<=159:
                return 0
            elif 160<=self.ldl<=189:
                return +2
            elif self.ldl>=190:
                return +2
    def hdl_cho_calc(self):
        if self.sex=="1":
            if self.hdl<35:
                return +2
            elif 36<=self.hdl<=44:
                return +1
            elif 45<=self.hdl<=49:
                return 0
            elif 50<=self.hdl<=59:
                return 0
            elif self.hdl>60:
                return -1
        elif self.sex=="2":
            if self.hdl<=35:
                return +5
            elif 36<=self.hdl<=44:
                return +2
            elif 45<=self.hdl<=49:
                return +1
            elif 50<=self.hdl<=59:
                return 0
            elif self.hdl>60:
                return -2
    def smoke_calc(self):
        if (self.smoke=='y' or self.smoke=='Y'):
                return 2
        elif (self.smoke=='n' or self.smoke=='N'):
                return 0
    def diabetes_calc(self):
        if (self.diabetes=='y' or self.diabetes=='Y'):
            if self.sex=='1':
                return 2
            elif self.sex=='2':
                return 4
        elif (self.diabetes=='n' or self.diabetes=='N'):
            return 0
    def bp_calc(self):
        if self.sex=="1":
            if self.bps<120 and self.bpd<80:
                return 0
            elif (120<=self.bps<=129) and (80<=self.bpd<=85):
                return 0
            elif (130<=self.bps<=139) and (85<=self.bpd<=89):
                return +1
            elif (140<=self.bps<=159) and (90<=self.bpd<=99):
                return +2
            elif self.bps>160 and self.bpd>100:
                return +3
        elif self.sex=="2":
            if self.bps<120 and self.bpd<80:
                return -3
            elif (120<=self.bps<=129) and (80<=self.bpd<=85):
                return 0
            elif (130<=self.bps<=139) and (85<=self.bpd<=89):
                return 0
            elif (140<=self.bps<=159) and (90<=self.bpd<=99):
                return +2
            elif self.bps>160 and self.bpd>100:
                return +3
a=HeartCal(sex,age,ldl,hdl,smoke,diabetes,bps,bpd)
res=a.age_calc()+a.ldl_cho_calc()+a.hdl_cho_calc()+a.bp_calc()+a.smoke_calc()+a.diabetes_calc()
print("Total Points",res)

if sex=="1":
    if res<=-3:
        res="1%"
        print("The PERSENTAGE of Heart Issue is : ",res)
    elif res==-2:
        res="2%"
        print("The PERSENTAGE of Heart Issue is : ",res)
    elif res==-1:
        res="2%"
        print("The PERSENTAGE of Heart Issue is : ",res)
    elif res==0:
        res="3%"
        print("The PERSENTAGE of Heart Issue is : ",res)
    elif res==1:
        res="4%"
        print("The PERSENTAGE of Heart Issue is : ",res)
    elif res==2:
        res="4%"
        print("The PERSENTAGE of Heart Issue is : ",res)
    elif res==3:
        res="6%"
        print("The PERSENTAGE of Heart Issue is : ",res)
    elif res==4:
        res="7%"
        print("The PERSENTAGE of Heart Issue is : ",res)
    elif res==5:
        res="9%"
        print("The PERSENTAGE of Heart Issue is : ",res)
    elif res==6:
        res="11%"
        print("The PERSENTAGE of Heart Issue is : ",res)
    elif res==7:
        res="14%"
        print("The PERSENTAGE of Heart Issue is : ",res)
    elif res==8:
        res="18%"
        print("The PERSENTAGE of Heart Issue is : ",res)
    elif res==9:
        res="22%"
        print("The PERSENTAGE of Heart Issue is : ",res)
    elif res==10:
        res="27%"
        print("The PERSENTAGE of Heart Issue is : ",res)
    elif res==11:
        res="33%"
        print("The PERSENTAGE of Heart Issue is : ",res)
    elif res==12:
        res="40%"
        print("The PERSENTAGE of Heart Issue is : ",res)
    elif res==14:
        res="47"
        print("The PERSENTAGE of Heart Issue is : ",res)
    elif res>14:
        res>"56%"
        print("The PERSENTAGE of Heart Issue is : ",res)
if sex=="2":
    if res<=-2:
        res="1%"
        print("The PERSENTAGE of Heart Issue is : ",res)
    elif res==-1:
        res="2%"
        print("The PERSENTAGE of Heart Issue is : ",res)
    elif res==0:
        res="2%"
        print("The PERSENTAGE of Heart Issue is : ",res)
    elif res==1:
        res="2%"
        print("The PERSENTAGE of Heart Issue is : ",res)
    elif res==2:
        res="3%"
        print("The PERSENTAGE of Heart Issue is : ",res)
    elif res==3:
        res="3%"
        print("The PERSENTAGE of Heart Issue is : ",res)
    elif res==4:
        res="4%"
        print("The PERSENTAGE of Heart Issue is : ",res)
    elif res==5:
        res="5%"
        print("The PERSENTAGE of Heart Issue is : ",res)
    elif res==6:
        res="6"
        print("The PERSENTAGE of Heart Issue is : ",res)
    elif res==7:
        res="7%"
        print("The PERSENTAGE of Heart Issue is : ",res)
    elif res==8:
        res="8%"
        print("The PERSENTAGE of Heart Issue is : ",res)
    elif res==9:
        res="9%"
        print("The PERSENTAGE of Heart Issue is : ",res)
    elif res==10:
        res="11%"
        print("The PERSENTAGE of Heart Issue is : ",res)
    elif res==11:
        res="13%"
        print("The PERSENTAGE of Heart Issue is : ",res)
    elif res==12:
        res="15%"
        print("The PERSENTAGE of Heart Issue is : ",res)
    elif res==13:
        res="17%"
        print("The PERSENTAGE of Heart Issue is : ",res)
    elif res==14:
        res="20%"
        print("The PERSENTAGE of Heart Issue is : ",res)
    elif res==15:
        res>"24%"
        print("The PERSENTAGE of Heart Issue is : ",res)
    elif res==16:
        res="27%"
        print("The PERSENTAGE of Heart Issue is : ",res)
    elif res17:
        res>"32%"
        print("The PERSENTAGE of Heart Issue is : ",res)
# Out:
# Enter a NAME : Arjun
# Enter a AGE : 45
# 1.Male
#                  2.Female1
# Enter a LDL CHOLESTEROL : 120
# Enter a HDL CHOLESTEROL : 56
# DO you SMOKE ?y/n : n
# You have a DIABETES ?y/n : y
# Enter a SYSTOLE : 130
# Enter a DIASToLE : 89
# Total Points 5
# The PERSENTAGE of Heart Issue is :  9
